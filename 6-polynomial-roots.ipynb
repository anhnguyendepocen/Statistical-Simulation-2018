# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
nls = [5, 10, 25, 50, 100]
#NPOINTS is for expected number of roots, using WLLN
NPOINTS = 5000

# %%
def poly_root(string, name):
    expected_real = np.zeros(len(nls))
    for idx, n in enumerate(nls):
        plt.figure(idx + 1)
        for itera in range(NPOINTS):
            coeff = np.zeros(n)
            coeff = string(n)
            root = np.roots(coeff)
            expected_real[idx] += np.isreal(root).sum()
        expected_real[idx] /= NPOINTS
        
        #plotting roots in complex plane
        plt.plot(root.real, root.imag, 'o', label = 'roots')
        plt.xlabel('Real Part')
        plt.ylabel('Imaginary Part')
        plt.legend()
        plt.title('Roots in the Complex Plane for  ' + name + ' coeffecients ' + str(n) + ' degree polynomial')
        plt.savefig('Image-Q6/' + name + '-' + str(n) +'.png')
    
    #plotting n vs expected number of real roots
    plt.figure(len(nls) + 1)
    plt.plot(nls, expected_real, 'go--')
    plt.xlabel('Degree of Polynomial')
    plt.ylabel('Expected Number of Real Roots')
    plt.title('Expected Number of Real Roots for ' + name + ' coeffecients ' + str(n) + ' degree polynomial')
    plt.savefig('Image-Q6/' + name + '-real-roots-' + str(n) +'.png')
    return expected_real

# %% [markdown]
# ## binomial distribution

# %%
def binom(n):
    x = np.random.uniform(low = 0.0, high=1.0, size = n)
    y= np.zeros(n)
    idx = x >0.5
    y[idx] = 1
    y[~idx] = -1
    return y

# %%
poly_root(binom, 'Binomial')
# Out:
# array([1.2476, 1.8248, 2.2584, 2.7564, 3.178 ])

# %% [markdown]
# ## Normal Distribution

# %%
def normal(n):
    a = np.zeros((2, n))
    u1 = np.random.uniform(size=n)
    u2 = np.random.uniform(size=n)
    a[0] = np.sqrt(-2*np.log(u1))* np.cos(2*np.pi*u2)
    a[1] = np.sqrt(-2*np.log(u1))* np.sin(2*np.pi*u2)
    return a[0]

# %%
poly_root(normal, 'Normal')
# Out:
# array([1.63  , 2.0612, 2.646 , 3.1132, 3.536 ])

# %% [markdown]
# ## Cauchy Distribution

# %%
def cauchy(n):
    u = np.random.uniform(size=n)
    return np.tan(np.pi*(u-0.5))

# %%
poly_root(normal, 'Cauchy')
# Out:
# array([1.6584, 2.0756, 2.6676, 3.1324, 3.5644])

# %% [markdown]
# ## Exponential Distribution

# %%
def expon(n):
    u = np.random.uniform(size=n)
    return -np.log(u)

# %%
poly_root(normal, 'Expo(0, 1)')
# Out:
# array([1.6576, 2.0848, 2.66  , 3.1416, 3.5444])
